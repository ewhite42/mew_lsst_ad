# %%
import sys
import warnings
sys.path.append("..")

from data.data_loader import normalised_subspace, subspace, scaler
from synthetic_anomalies.generation import anomaly_dataset
import seaborn as sns

from sklearn.metrics import roc_auc_score, log_loss
from sklearn.metrics import balanced_accuracy_score, roc_auc_score
from sklearn.manifold import TSNE
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import precision_score, recall_score, f1_score, fbeta_score

from benchmark import anom_types, models, model_outputs, init_algos
from evaluation import algo_results, algo_rank_results, result_df, plot_results
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

import scienceplots
plt.style.use('science')

# %%
## create a dataset with both normal samples and synthetic anomalies, generated 
## by utilizing the Gaussian mixture model trained on LSST simulation data -MEW

output = anomaly_dataset(
    anom_size=1000
)
# Out:
# /home/ellie/src/anaconda3/envs/lsst/lib/python3.12/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator GaussianMixture from version 1.3.0 when using version 1.4.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
## apply a mask to the global anomalies in the generated data set to select only the samples
## that have log-likelihood score >= 0, and all normal samples with label 0 -MEW
global_df = output[~((output["label"] == 1) & (output["score"] >= 0)) & ((output["label"] == 1) | (output["label"] == 0))]

## determine what percentage of the (now-filtered) dataset consists of global anomalies -MEW
contamination_global = len(global_df[global_df["label"] == 1])/len(global_df)

## convert dataset with global anomalies filtered to a numpy array -MEW
global_df = global_df.to_numpy()

# %%
## print the ratio of global anomalies to normal samples -MEW
contamination_global
# Out:
# 0.0068132610293387364

# %%
## apply a mask to the cluster anomalies in the generated data set to select only the samples
## that have log-likelihood score >= 0, and all normal samples with label 0 -MEW
cluster_df = output[~((output["label"] == 3) & (output["score"] >= 0)) & ((output["label"] == 3) | (output["label"] == 0))]

## determine what percentage of the (now-filtered) dataset consists of cluster anomalies -MEW
contamination_cluster = len(cluster_df[cluster_df["label"] == 3])/len(cluster_df)

## convert dataset with cluster anomalies filtered to a numpy array -MEW
cluster_df = cluster_df.to_numpy()

# %%
## select all local anomalies and normal samples -- no log likelihood score filter on this one, 
## because local outliers are sampled from the model's components  -MEW
local_df = output[(output["label"] == 0) | (output["label"] == 2)].to_numpy()
#print(output)

## determine what percentage of the (local-anomaly filtered) dataset consists of local anomalies -MEW
contamination_local = len(output[output["label"] == 2])/len(local_df)

# %%
## plot a versus sin(i) of the synthetic cluster anomalies -MEW
plt.scatter(
    output[output["label"] == 3].to_numpy()[:, 2], output[output["label"] == 3].to_numpy()[:, 3], s=1
)

# %%
## plot all the points of the generated data set: normal samples, and local, global, and cluster anomalies -MEW
plt.subplots(figsize=(8,8))
plt.ylim(0, .6)

## normal samples
plt.scatter(
    output[output["label"] == 0].to_numpy()[:, 2], output[output["label"] == 0].to_numpy()[:, 3], s=.01, alpha=.5
)

## local anomalies
plt.scatter(
    output[output["label"] == 2].to_numpy()[:, 2], output[output["label"] == 2].to_numpy()[:, 3], s=1, c="green"
)

## global anomalies
plt.scatter(
    output[output["label"] == 1].to_numpy()[:, 2], output[output["label"] == 1].to_numpy()[:, 3], s=.1, c="red"
)

## cluster anomalies
plt.scatter(
    output[output["label"] == 3].to_numpy()[:, 2], output[output["label"] == 3].to_numpy()[:, 3], s=.1, c="black"
)

# %% [markdown]
# ## Local anomalies

# %%
## returns F1 score and balanced accuracy metric for each of the 9 unsupervised anomaly detection
## methods from PyOD as applied to the dataset with local anomalies injected -MEW

with warnings.catch_warnings(): # Remove parameter update warning from sklearn implementatio - clean output, that's all.
    warnings.simplefilter("ignore")

    ## 
    local_scores_with_noise = algo_results(
        data = local_df,
        models = init_algos(
            contamination = contamination_local
        ), ## create instances of each of the nine anomaly detection methods -MEW
        label = 2,
        noise_level = .25,
        with_noise = True
    )
# Out:
# KNN
# Accuracy metric: {'BAL_ACC': [0.7340857158715116, 0.7300137406404918, 0.7203365590605266, 0.7445656339503945, 0.7473349060136079, 0.7560788164783141, 0.7316830860321499, 0.7475015615699041, 0.7553788631418699, 0.7445656339503945], 'F1': [0.48106904231625836, 0.4851258581235698, 0.4444444444444444, 0.4808510638297872, 0.5022026431718062, 0.5130434782608696, 0.4713656387665198, 0.5077951002227171, 0.49064449064449067, 0.4808510638297872]})
# ------
# IForest
# Accuracy metric: {'BAL_ACC': [0.6488520442249518, 0.6504213962828322, 0.6773197499021357, 0.6454800223303763, 0.6884329590949443, 0.6558266159642221, 0.6727811391134864, 0.6382054705897727, 0.6559266092979998, 0.6579625969135097], 'F1': [0.3063457330415755, 0.2976939203354298, 0.3494736842105263, 0.32075471698113206, 0.3689727463312369, 0.32516703786191536, 0.33962264150943394, 0.2947845804988662, 0.3273542600896861, 0.3274336283185841]})
# ------
# LOF
# Accuracy metric: {'BAL_ACC': [0.7202698968380081, 0.7340190536489931, 0.7068540511396156, 0.7298137539729364, 0.7540761599740634, 0.7227725200111476, 0.716697888275877, 0.7185672203350908, 0.7266111774633527, 0.6923354889409722], 'F1': [0.44251626898047725, 0.4789356984478936, 0.4164859002169197, 0.4785553047404063, 0.5165562913907285, 0.45474613686534215, 0.4608294930875576, 0.45393258426966293, 0.4449152542372881, 0.4168618266978923]})
# ------
# ABOD
# Accuracy metric: {'BAL_ACC': [0.7542761466416189, 0.7445323028391353, 0.7380243666574945, 0.7559121609220179, 0.738091028880013, 0.7271778063547599, 0.7445323028391353, 0.7115593174845612, 0.7290471384139736, 0.7487042714039329], 'F1': [0.5234899328859061, 0.47983014861995754, 0.4731182795698925, 0.5075268817204301, 0.47516198704103674, 0.46153846153846156, 0.47983014861995754, 0.43171806167400884, 0.45493562231759654, 0.4791666666666667]})
# ------
# CBLOF
# Accuracy metric: {'BAL_ACC': [0.622889751549603, 0.6099738725200993, 0.5771675427218215, 0.6016632665017634, 0.6018299220580596, 0.5778341649470065, 0.575064892883793, 0.5793368547823684, 0.6166484642580362, 0.5820394646230633], 'F1': [0.23694779116465864, 0.2194616977225673, 0.1648590021691974, 0.21120689655172414, 0.21350762527233116, 0.17233560090702948, 0.16192560175054704, 0.16846652267818574, 0.23140495867768596, 0.17817371937639198]})
# ------
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 8
#       5 warnings.simplefilter("ignore")
#       7 ##
# ----> 8 local_scores_with_noise = algo_results(
#       9     data = local_df,
#      10     models = init_algos(
#      11         contamination = contamination_local
#      12     ), ## create instances of each of the nine anomaly detection methods -MEW
#      13     label = 2,
#      14     noise_level = .25,
#      15     with_noise = True
#      16 )
#
# File ~/research/lsst/mew_lsst_ad/ad_benchmark/evaluation.py:55, in algo_results(data, models, label, iterations, with_noise, noise_level, silent)
#      45     X_train, X_test, y_train, y_test = train_test_split(
#      46         data[:, 0:5],
#      47         data[:, 5],
#    (...)
#      51         shuffle=True
#      52     )
#      54 ## fit the model that's selected in the loop to the X training set -MEW
# ---> 55 clf.fit(X_train)
#      57 ## get the prediction from the test data (returns outlier labels, 0 or 1) -MEW, from PyOD docs
#      58 y_test_pred = clf.predict(X_test)
#
# TypeError: CD.fit() missing 1 required positional argument: 'y'

# %%
## create a Pandas dataframe where each row corresponds to a score (either F1 or BAL_ACC) for
## one iteration over one model, where the model (algorithm), metric (F1 etc), anomaly type, and 
## score are the columns. Drop the anomaly type column as we don't need it, and group by Algorithm 
## and metric -MEW
local_results = result_df(
    local_scores_with_noise, anom_type = "local"
).drop(columns=["type"]).groupby(by=["Algorithm", "metric"])#.mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 6
#       1 ## create a Pandas dataframe where each row corresponds to a score (either F1 or BAL_ACC) for
#       2 ## one iteration over one model, where the model (algorithm), metric (F1 etc), anomaly type, and
#       3 ## score are the columns. Drop the anomaly type column as we don't need it, and group by Algorithm
#       4 ## and metric -MEW
#       5 local_results = result_df(
# ----> 6     local_scores_with_noise, anom_type = "local"
#       7 ).drop(columns=["type"]).groupby(by=["Algorithm", "metric"])
#
# NameError: name 'local_scores_with_noise' is not defined

# %%
## print a table describing the results of the analysis above -MEW
local_results.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 ## print a table describing the results of the analysis above -MEW
# ----> 2 local_results.describe()
#
# NameError: name 'local_results' is not defined

# %% [markdown]
# ## Global anomalies

# %%
## returns F1 score and balanced accuracy metric for each of the 9 unsupervised anomaly detection
## methods from PyOD as applied to the dataset with global anomalies injected -MEW

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    global_scores_with_noise = algo_results(
    data = global_df,
    models = init_algos(
        contamination = contamination_global
    ),
    label = 1,
    noise_level=.25
)
# Out:
# KNN
# Accuracy metric: {'BAL_ACC': [0.8273141439693494, 0.7833211704015054, 0.7883737575389711, 0.8448913347297315, 0.8011983411632206, 0.7882404330939341, 0.8137562758973963, 0.8272474817468309, 0.7837544748478756, 0.7877404664250454], 'F1': [0.6302521008403361, 0.5603448275862069, 0.619718309859155, 0.6556016597510375, 0.6106194690265486, 0.608294930875576, 0.5829959514170041, 0.625, 0.593607305936073, 0.5689655172413793]})
# ------
# IForest
# Accuracy metric: {'BAL_ACC': [0.6729720942580436, 0.6821773285289753, 0.6721388164765624, 0.7260369776517823, 0.6462896625605077, 0.6993545459542463, 0.6727721075904881, 0.6995545326218018, 0.6690527649033924, 0.642037022093264], 'F1': [0.3508771929824561, 0.3870967741935483, 0.3162055335968379, 0.4581497797356828, 0.2918454935622318, 0.39655172413793105, 0.3418803418803419, 0.4070796460176991, 0.3661971830985915, 0.2894736842105263]})
# ------
# LOF
global_results = result_df(
    global_scores_with_noise, anom_type = "global"
).groupby(by=["Algorithm", "metric"])

# %%
## print a table describing the results of the analysis above -MEW
global_results.describe()
# Out:
#                         score                                          \
#                         count      mean       std       min       25%
# Algorithm       metric
# ABOD            BAL_ACC  10.0  0.739972  0.025039  0.699655  0.730440
#                 F1       10.0  0.472881  0.038199  0.408333  0.465941
# CBLOF           BAL_ACC  10.0  0.501363  0.003483  0.495934  0.499795
#                 F1       10.0  0.010334  0.006902  0.000000  0.007915
# CD              BAL_ACC  10.0  0.658401  0.041861  0.589372  0.624740
#                 F1       10.0  0.273419  0.049359  0.193548  0.234437
# COPOD           BAL_ACC  10.0  0.642130  0.021303  0.611335  0.630167
#                 F1       10.0  0.292682  0.036843  0.235294  0.275618
# Feature Bagging BAL_ACC  10.0  0.689363  0.029415  0.616321  0.682791
#                 F1       10.0  0.384322  0.051037  0.264706  0.370182
# HBOS            BAL_ACC  10.0  0.728835  0.026648  0.686930  0.711899
#                 F1       10.0  0.471687  0.038776  0.415459  0.442657
# IForest         BAL_ACC  10.0  0.678239  0.025190  0.642037  0.669824
#                 F1       10.0  0.360536  0.053649  0.289474  0.322624
# KNN             BAL_ACC  10.0  0.804584  0.022236  0.783321  0.787865
#                 F1       10.0  0.605540  0.029365  0.560345  0.585649
# LOF             BAL_ACC  10.0  0.702827  0.024136  0.668786  0.683862
#                 F1       10.0  0.399317  0.032735  0.352941  0.379858
#
#
#                               50%       75%       max
# Algorithm       metric
# ABOD            BAL_ACC  0.739278  0.746779  0.782788
#                 F1       0.476395  0.492898  0.524194
# CBLOF           BAL_ACC  0.500736  0.504806  0.505305
#                 F1       0.008909  0.017022  0.018182
# CD              BAL_ACC  0.669563  0.692047  0.710913
#                 F1       0.288113  0.304779  0.346290
# COPOD           BAL_ACC  0.637518  0.659126  0.676625
#                 F1       0.277056  0.325189  0.352381
# Feature Bagging BAL_ACC  0.696878  0.704024  0.721684
#                 F1       0.383484  0.418085  0.453333
# HBOS            BAL_ACC  0.724294  0.745757  0.778902
#                 F1       0.477618  0.487786  0.551724
# IForest         BAL_ACC  0.672872  0.695060  0.726037
#                 F1       0.358537  0.394188  0.458150
# KNN             BAL_ACC  0.794786  0.823875  0.844891
#                 F1       0.609457  0.623680  0.655602
# LOF             BAL_ACC  0.699271  0.720096  0.738828
#                 F1       0.398153  0.422632  0.456432

# %% [markdown]
# ## Cluster anomalies

# %%
## returns F1 score and balanced accuracy metric for each of the 9 unsupervised anomaly detection
## methods from PyOD as applied to the dataset with global anomalies injected -MEW

with warnings.catch_warnings(): # Remove parameter update warning from sklearn implementatio - clean output, that's all.
    warnings.simplefilter("ignore")
    cluster_scores_with_noise = algo_results(
        data = cluster_df,
        models = init_algos(
            contamination_cluster
        ),
        label = 3.,
        noise_level=.25
    )
# Out:
# KNN
# ------
# Feature Bagging
# Accuracy metric: {'BAL_ACC': [0.49488355277531376, 0.5107736126593994, 0.5534110378042923, 0.5062990934424323, 0.5175062538409848, 0.5128984101789807, 0.506132437886136, 0.5155231743674509, 0.5280302481051141, 0.5346628959529218], 'F1': [0.007421150278293135, 0.03900709219858156, 0.11992945326278659, 0.030131826741996232, 0.05128205128205128, 0.043165467625899276, 0.029850746268656712, 0.04878048780487805, 0.072992700729927, 0.08391608391608392]})
# ------
# HBOS
# Accuracy metric: {'BAL_ACC': [0.7470584686081756, 0.7133118132757086, 0.6696495172827894, 0.7139451043896343, 0.7213443677964049, 0.7556492584192684, 0.6838480840936638, 0.7139117732783751, 0.7088039629474823, 0.6940720983564599], 'F1': [0.49729729729729727, 0.42553191489361697, 0.35820895522388063, 0.44036697247706424, 0.45421245421245415, 0.4965277777777778, 0.37410071942446044, 0.43956043956043955, 0.4398496240601503, 0.4128787878787879]})
# ------

# %%
## creates a Pandas dataframe as shown above for the local and global anomalies, though
## this time warnings are caught and ignored. The display function is also called here to 
## print a table summarizing the data, as before

with warnings.catch_warnings(): # Remove parameter update warning from sklearn implementatio - clean output, that's all.
    warnings.simplefilter("ignore")
    cluster_results = result_df(
        cluster_scores_with_noise, anom_type = "cluster"
    ).groupby(by=["Algorithm", "metric"]).describe()
    cluster_results

# %% [markdown]
# ## Global ranking

# %%
with warnings.catch_warnings(): # Remove parameter update warning from sklearn implementatio - clean output, that's all.
    warnings.simplefilter("ignore")

    ## calculates the ranking metric by calculating what fraction of
    ## the top 500 most anomalous synthetic global anomaly samples
    ## were in the top 500 most anomalous samples identified by each
    ## different unsupervised anomaly detection algorithm -MEW
    
    global_rank_scores_with_noise = algo_rank_results(
        data = global_df,
        models = init_algos(
            contamination = contamination_global
        ),
        label = 1,
        #with_noise = False,
        noise_level=.25
    )

# %%
## print a table describing the results of the analysis above -MEW
pd.DataFrame(global_rank_scores_with_noise).describe()
# Out:
#              KNN    IForest        LOF       ABOD      CBLOF         CD  \
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    0.761200   0.479200   0.417000   0.702200   0.392200   0.520600
# std     0.015002   0.034797   0.024445   0.017087   0.034208   0.014909
# min     0.732000   0.428000   0.378000   0.676000   0.358000   0.496000
# 25%     0.752000   0.455000   0.403000   0.689500   0.363500   0.510500
# 50%     0.762000   0.481000   0.406000   0.701000   0.384000   0.521000
# 75%     0.769500   0.499000   0.439000   0.713000   0.415000   0.534000
# max     0.786000   0.534000   0.452000   0.732000   0.446000   0.538000
#
#            COPOD  Feature Bagging      HBOS
# count  10.000000        10.000000  10.00000
# mean    0.470400         0.464600   0.50700
# std     0.016754         0.024874   0.01212
# min     0.446000         0.422000   0.48600
# 25%     0.456500         0.456000   0.49750
# 50%     0.469000         0.459000   0.51100
# 75%     0.482000         0.478000   0.51350
# max     0.494000         0.510000   0.52400

# %% [markdown]
# ## Cluster ranking evaluation

# %%
## see description above for global ranking evaluation; the idea
## is the same -MEW

cluster_rank_scores_with_noise = algo_rank_results(
    data = cluster_df,
    models = init_algos(
        contamination = contamination_global
    ),
    label = 3,
    #with_noise = False,
    noise_level= .25
)
# Out:
# /Users/br/Desktop/lsst_ad_git/ad_lsst/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/br/Desktop/lsst_ad_git/ad_lsst/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/br/Desktop/lsst_ad_git/ad_lsst/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/br/Desktop/lsst_ad_git/ad_lsst/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/br/Desktop/lsst_ad_git/ad_lsst/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/br/Desktop/lsst_ad_git/ad_lsst/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/br/Desktop/lsst_ad_git/ad_lsst/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/br/Desktop/lsst_ad_git/ad_lsst/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/br/Desktop/lsst_ad_git/ad_lsst/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/br/Desktop/lsst_ad_git/ad_lsst/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
## print a table describing the results of the analysis above -MEW
pd.DataFrame(cluster_rank_scores_with_noise).describe()
# Out:
#              KNN    IForest        LOF       ABOD      CBLOF         CD  \
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    0.398400   0.643600   0.219800   0.366400   0.630600   0.660800
# std     0.011187   0.019179   0.009496   0.008834   0.012474   0.019982
# min     0.374000   0.618000   0.204000   0.350000   0.602000   0.630000
# 25%     0.392000   0.629000   0.214500   0.362000   0.630000   0.645500
# 50%     0.401000   0.643000   0.217000   0.367000   0.633000   0.665000
# 75%     0.406500   0.657000   0.227000   0.369500   0.638500   0.675000
# max     0.410000   0.672000   0.234000   0.382000   0.644000   0.684000
#
#            COPOD  Feature Bagging       HBOS
# count  10.000000        10.000000  10.000000
# mean    0.478800         0.303200   0.504800
# std     0.013959         0.027312   0.032731
# min     0.456000         0.256000   0.460000
# 25%     0.471500         0.285000   0.492000
# 50%     0.478000         0.302000   0.499000
# 75%     0.487000         0.323000   0.524500
# max     0.500000         0.348000   0.566000

# %% [markdown]
# ## Local ranking evaluation

# %%
import joblib 
from evaluation import algo_rank_local_results

## load the Gaussian mixture model and retrieve its parameters -MEW
anom_gen = joblib.load(open("../synthetic_anomalies/gmm/gmm.joblib", "rb"))
params = anom_gen._get_parameters()

# %%
## compute the distances between samples and the centroids of their associated GMM 
## components -MEW
arr = np.vectorize(lambda x: params[1][int(x)][0])(local_df[:, 7]).reshape(-1, 1)
for i in range(1, 5):
    arr = np.hstack((arr, np.vectorize(lambda x: params[1][int(x)][int(i)])(local_df[:, 7]).reshape(-1, 1)))

centroid_dist = np.linalg.norm(scaler.inverse_transform(arr) - local_df[:, 0:5], axis=1)

scaled_centroid_dist = (centroid_dist - centroid_dist.min())
scaled_centroid_dist /= scaled_centroid_dist.max()

# %%
from sklearn.model_selection import train_test_split

def algo_rank_local_results(data, label, iterations = 10, with_noise=True, noise_level = 0, silent = False):
    rank_scores = {key : [] for key in models}
    '''if anom_type == "local":
        idx = -1
    else:'''
    idx = -1

    for i in range(iterations):
        if with_noise:
            duplicate_idx = np.random.choice(500, size=100, replace=False)

            noisy_features = data[:, :5] + noise_level*data[:, -6:-1]
            noisy_features =  np.concatenate([noisy_features, noisy_features[duplicate_idx, 0:5]]) # Add duplicates

            noisy_scores = np.concatenate([data[:, idx], data[duplicate_idx, idx]])
            noisy_labels = np.concatenate([data[:, 5], data[duplicate_idx, 5]])

            # Should I make use of training score?
            X_train, X_test, y_train, y_test = train_test_split(
                noisy_features, 
                noisy_scores, 
                test_size=.3,
                #random_state=42,
                stratify=noisy_labels,
                shuffle=True
            )
                    
        else:
            X_train, X_test, y_train, y_test = train_test_split(
                data[:, 0:5], 
                data[:, idx], # score column of dataset
                test_size=.3,
                #random_state=42,
                stratify=data[:, 5],
                shuffle=True
            )

        rn_model_idx = np.argsort(y_test)[-500::]

        for name, clf in zip(models.keys(), models.values()):
            
            clf.fit(X_train)
            # get the prediction labels and outlier scores of the training data
            #y_train_pred = clf.labels_  # binary labels (0: inliers, 1: outliers)
            #y_train_scores = clf.decision_scores_  # raw outlier scores
            

            # get the prediction on the test data
            #y_test_pred = clf.predict(X_test)  # outlier labels (0 or 1)
            y_test_scores = clf.decision_function(X_test)  # outlier scoress
            
            '''rn_algo_scores = y_test_scores - y_test_scores.min()
            rn_algo_scores /= rn_algo_scores.max()
            
            rn_model_scores = abs(y_test - y_test.max())
            rn_model_scores /= rn_model_scores.max()
            '''
            #acc = balanced_accuracy_score(y_test, label*y_test_pred)
            #model_scores = anom_gen.gmm.score_samples(X_test)
            ''' print(np.argsort(y_test_scores)[::-1])
                print(np.argsort(y_test))'''
            #print(y_test_scores, model_scores.min())


            err_score = len(np.intersect1d(rn_model_idx, np.argsort(y_test_scores)[-500::])) / 500 # Overlap of the top 100 outliers.
            rank_scores[name].append(err_score)
            
            #rank_scores[name].append(kendalltau(rn_model_scores, rn_algo_scores).correlation)
            #print(f"Name: {name}, spearman: {spearmanr(rn_model_scores, rn_algo_scores)}")
            '''if not silent:
                print(name)
                print(f"Accuracy metric: {rank_scores[name]})")
                print(("------"))'''

    return rank_scores

# %%
## calculate the ranking metric for local anomalies by determining the ratio
## of the number of samples that the unsupervised AD algorithm identified as most 
## anomalous (ranked by the Euclidean distance between the sample and the centroid of
## the model component it is associated with) to the number of anomalous samples 
## that were synthetically generated. -MEW

with warnings.catch_warnings(): # Remove parameter update warning from sklearn implementatio - clean output, that's all.
    warnings.simplefilter("ignore")
    local_rank_scores_with_noise = algo_rank_local_results(
        data = np.hstack((local_df, scaled_centroid_dist.reshape(-1,1))),
        label = 2,
        #with_noise = False,
        noise_level=.25
    )

# %%
## show results in a data table
pd.DataFrame(local_rank_scores_with_noise).describe()
# Out:
#            KNN    IForest       LOF       ABOD      CBLOF         CD  \
# count  10.0000  10.000000  10.00000  10.000000  10.000000  10.000000
# mean    0.3028   0.456800   0.20700   0.285400   0.625800   0.387600
# std     0.0129   0.033628   0.01772   0.017258   0.049175   0.112118
# min     0.2840   0.418000   0.18600   0.264000   0.540000   0.260000
# 25%     0.2940   0.439000   0.18900   0.268000   0.589000   0.290500
# 50%     0.3030   0.451000   0.20800   0.286000   0.650000   0.381000
# 75%     0.3130   0.465500   0.22000   0.299000   0.665500   0.486500
# max     0.3220   0.540000   0.23400   0.310000   0.670000   0.528000
#
#            COPOD  Feature Bagging       HBOS
# count  10.000000        10.000000  10.000000
# mean    0.376200         0.244600   0.293200
# std     0.010768         0.032001   0.040871
# min     0.354000         0.202000   0.242000
# 25%     0.370000         0.215000   0.264000
# 50%     0.378000         0.251000   0.275000
# 75%     0.384000         0.267500   0.325000
# max     0.388000         0.284000   0.356000

# %%
## TSNE is a method that allows us to plot the 5-dimensional GMM generated anomaly data 
## in a 2 dimensional plot to visualize the overall structure of the data -MEW

tsne = TSNE()
X_embed = tsne.fit_transform(output.to_numpy()[:, 0:5])

output["tsne_x"] = X_embed[:, 0]
output["tsne_y"] = X_embed[:, 1]

# %%
fig = plt.figure(figsize=(10, 6))

# Create a grid for the main plot and the panel
main_grid = fig.add_gridspec(1, 2, width_ratios=[3, 1])

# Main plot
main_plot = fig.add_subplot(main_grid[0, 0])

## plot the normal samples generated by the GMM in the main plot -MEW
main_plot.scatter(
    output[output["label"] == 0]["tsne_x"],
    output[output["label"] == 0]["tsne_y"],
    s=.5,
    marker="o",
    label="Normal"
)

## plot the global anomaly samples generated by the GMM in the main plot -MEW
main_plot.scatter(
    output[output["label"] == 1]["tsne_x"],
    output[output["label"] == 1]["tsne_y"],
    s=2,
    marker="o",
    c="r",
    label="Global"
)

## plot the local anomaly samples generated by the GMM in the main plot -MEW
main_plot.scatter(
    output[output["label"] == 2]["tsne_x"],
    output[output["label"] == 2]["tsne_y"],
    s=2,
    marker="o",
    c="black",
    label="Local"
)

## plot the cluster anomaly samples generated by the GMM in the main plot -MEW
main_plot.scatter(
    output[output["label"] == 3]["tsne_x"],
    output[output["label"] == 3]["tsne_y"],
    s=2,
    marker="o",
    c="orange",
    alpha=.5,
    label="Cluster"
)

## set the x and y labels of the main plot -MEW
main_plot.set_xlabel("t-SNE X", fontsize=20)
main_plot.set_ylabel("t-SNE Y", fontsize=20)

# Panel with subplots
panel_grid = main_grid[0, 1].subgridspec(3, 1, hspace=0.3)

# Create three smaller subplots in the panel
#for i in range(3):

## plot a small section of the main plot with the normal samples 
## and the global anomalies overlaid -MEW
ax = fig.add_subplot(panel_grid[0, 0])
ax.scatter(
    output[(output["label"] == 0)]["tsne_x"],
    output[output["label"] == 0]["tsne_y"],
    s=1,
    marker="o",
)
ax.scatter(
    output[(output["label"] == 1)]["tsne_x"],
    output[output["label"] == 1]["tsne_y"],
    s=4,
    marker="o",
    c="r"
)


ax.set_xlim(-100,-50)
ax.set_ylim(30,80)
ax.set_title(f"Global")

## plot a small section of the main plot with the normal samples 
## and the local anomalies overlaid -MEW
ax = fig.add_subplot(panel_grid[1, 0])

ax.scatter(
    output[(output["label"] == 0)]["tsne_x"],
    output[output["label"] == 0]["tsne_y"],
    s=1,
    marker="o",
)
ax.scatter(
    output[(output["label"] == 2)]["tsne_x"],
    output[output["label"] == 2]["tsne_y"],
    s=4,
    marker="o",
    c="black"
)
ax.set_xlim(80,130)
ax.set_ylim(-40,30)
ax.set_title(f"Local")

## plot a small section of the main plot with the normal samples 
## and the cluster anomalies overlaid -MEW
ax = fig.add_subplot(panel_grid[2, 0])
ax.scatter(
    output[(output["label"] == 0)]["tsne_x"],
    output[output["label"] == 0]["tsne_y"],
    s=1,
    marker="o",
)
ax.scatter(
    output[(output["label"] == 3)]["tsne_x"],
    output[output["label"] == 3]["tsne_y"],
    s=4,
    marker="o",
    c="orange",
)
ax.set_ylim(50, 130)
ax.set_xlim(-40,60)
ax.set_title(f"Cluster")

# Adjust layout
plt.tight_layout()
legend = main_plot.legend(loc="upper right", fontsize=12, scatterpoints=1)
legend.legend_handles[0]._sizes = [30]
legend.legend_handles[1]._sizes = [30]
legend.legend_handles[2]._sizes = [30]
legend.legend_handles[3]._sizes = [30]

#plt.savefig("anom_types.png", dpi=500)
# Show the plot
plt.show()
